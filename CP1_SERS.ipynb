# %% [markdown]
# <a href="https://colab.research.google.com/github/Camper-Lingo/CP1_SERS/blob/main/CP1_SERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dataset 1 — Appliances Energy Prediction  (UCI)**
#
# Fonte: https://archive.ics.uci.edu/dataset/374/appliances+energy+prediction
#
# **Situação**
#
# Uma empresa de eficiência energética está analisando o comportamento de uma residência de baixo consumo. A equipe deseja identificar períodos de consumo elevado dos eletrodomésticos e observar quais condições de temperatura e umidade estavam presentes nesses momentos.

# %% [markdown]
# ![untitled.svg](data:image/svg+xml;base64,...)

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/energydata_SAMPLE.csv')

# %%
df1.head()
# Out:
#    Appliances  lights       T1     RH_1       T2     RH_2       T3     RH_3
# 0          40       0  20.8900  35.4000  17.7600  39.1633  20.2900  36.9000
# 1          90      10  21.8900  53.1000  21.2900  45.3600  21.6333  49.2267
# 2          50       0  21.3900  35.5000  17.6333  40.5300  21.6667  35.2000
# 3          50       0  21.3900  41.0333  23.8900  34.8400  22.0333  36.9333
# 4          70       0  19.9633  35.1267  16.4633  40.1267  20.0000  36.4000

# %%
df1.shape
# Out:
# (1974, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1974 entries, 0 to 1973
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Appliances  1974 non-null   int64
#  1   lights      1974 non-null   int64
#  2   T1          1974 non-null   float64
#  3   RH_1        1974 non-null   float64
#  4   T2          1974 non-null   float64
#  5   RH_2        1974 non-null   float64
#  6   T3          1974 non-null   float64
#  7   RH_3        1974 non-null   float64
# dtypes: float64(6), int64(2)
# memory usage: 123.5 KB

# %%
df1.describe()
# Out:
#         Appliances       lights           T1         RH_1           T2  \
# count  1974.000000  1974.000000  1974.000000  1974.000000  1974.000000
# mean     93.044580     3.839919    21.664703    40.219193    20.293635
# std      93.826149     7.937076     1.574883     3.971923     2.126958
# min      20.000000     0.000000    16.790000    27.733300    16.100000
# 25%      50.000000     0.000000    20.700000    37.205825    18.790000
# 50%      60.000000     0.000000    21.600000    39.590000    20.000000
# 75%     100.000000     0.000000    22.600000    42.991675    21.500000
# max     770.000000    50.000000    26.260000    57.496700    28.917500
#
#               RH_2           T3         RH_3
# count  1974.000000  1974.000000  1974.000000
# mean     40.411386    22.231615    39.209733
# std       4.037686     1.957275     3.288818
# min      24.063300    17.200000    30.133300
# 25%      37.760000    20.700000    36.900000
# 50%      40.433300    22.100000    38.433300
# ...

# %%
df1.columns
# Out:
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3'], dtype='object')

# %%
# 2.	Renomeie Appliances para Consumo_Eletrodomesticos e simplifique
#  o nome de pelo menos três atributos ambientais.
df1.rename(columns={'Appliances': 'Consumo_Eletrodomesticos',
                    'T1': 'Temperatura_01',
                    'RH_1': 'Umidade_01'}, inplace=True)

# %%
#Determine o maior consumo de eletrodomésticos registrado na amostra.
df1['Consumo_Eletrodomesticos'].max()
# Out:
# 770

# %%
#Calcule um limiar correspondente a 70% do valor máximo e crie um DataFrame contendo somente os registros acima desse limite.
limiar = 0.70 * df1['Consumo_Eletrodomesticos'].max()

df_acima_70 = df1[df1['Consumo_Eletrodomesticos'] > limiar]

print(limiar)
print(df_acima_70)
# Out:
# 539.0
#       Consumo_Eletrodomesticos  lights  Temperatura_01  Umidade_01       T2  \
# 352                        620       0         24.3900     44.3333  25.3700
# 427                        650       0         20.8900     36.7000  18.2900
# 453                        560      30         21.3567     36.0900  19.5667
# 616                        570      10         24.8900     32.6667  23.5600
# 696                        590      30         19.8567     47.6633  18.7000
# 744                        740      20         19.5000     42.1333  18.2600
# 916                        750      30         22.4300     43.0000  21.9267
# 993                        690      10         22.5333     45.0267  22.0667
# 1026                       560       0         21.0000     38.9000  19.2900
# 1173                       580       0         21.6000     34.6267  19.5000
# 1182                       600      20         24.8900     48.1333  28.9175
# ...

# %%
#Conte os registros selecionados e calcule qual percentual da amostra eles representam.

quantidade = len(df_acima_70)
percentual = (quantidade / len(df1)) * 100

print("Quantidade de registros:", quantidade)
print("Percentual da amostra:", percentual, "%")


#Calcule a temperatura média de T1 e crie outro DataFrame contendo simultaneamente consumo acima de 70% do máximo e temperatura acima da média.


temperatura_media = df1['Temperatura_01'].mean()

df_acima_70_temp = df1[
    (df1['Consumo_Eletrodomesticos'] > limiar) &
    (df1['Temperatura_01'] > temperatura_media)
]

print("Temperatura média:", temperatura_media)
print(df_acima_70_temp)


#Compare os dois DataFrames e explique o efeito da inclusão da temperatura como segundo critério.

print("Registros acima de 70%:", len(df_acima_70))
print("Registros acima de 70% e temperatura acima da média:", len(df_acima_70_temp))
# Out:
# Quantidade de registros: 22
# Percentual da amostra: 1.1144883485309016 %
# Temperatura média: 21.664702634245188
#       Consumo_Eletrodomesticos  lights  Temperatura_01  Umidade_01       T2  \
# 352                        620       0         24.3900     44.3333  25.3700
# 616                        570      10         24.8900     32.6667  23.5600
# 916                        750      30         22.4300     43.0000  21.9267
# 993                        690      10         22.5333     45.0267  22.0667
# 1182                       600      20         24.8900     48.1333  28.9175
# 1196                       580       0         23.6333     47.2267  24.8140
# 1835                       720      10         22.2000     37.9333  21.1000
# 1964                       620       0         22.7000     41.7233  22.4267
#
#          RH_2       T3     RH_3
# 352   37.7360  26.7300  38.8633
# 616   31.1400  23.6000  30.8233
# 916   40.1333  21.2300  42.5967
# 993   39.7900  22.3900  41.9300
# ...

# %% [markdown]
# #DataSet 2 - Steel Industry Energy Consumption (UCI)

# %%
import pandas as pd

dados = pd.read_csv("amostra_dataset2_steel.csv")

dados.head()
# Out:
#                date  Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# 0  29/04/2018 07:15       2.88                                  3.82
# 1  04/10/2018 12:00      60.77                                 48.02
# 2  26/01/2018 11:30     120.42                                 59.65
# 3  02/06/2018 14:30       3.13                                  0.00
# 4  07/12/2018 15:00      58.86                                 20.99
#
#    Leading_Current_Reactive_Power_kVarh  Lagging_Current_Power_Factor  \
# 0                                   0.0                         60.20
# 1                                   0.0                         78.46
# 2                                   0.0                         89.61
# 3                                  16.6                        100.00
# 4                                   0.0                         94.19
#
#    Leading_Current_Power_Factor WeekStatus Day_of_week     Load_Type
# ...

# %%
dados = dados.rename(columns={
    "Usage_kWh": "Consumo_kWh",
    "Lagging_Current_Power_Factor": "FP_Atraso",
    "Leading_Current_Power_Factor": "FP_Avanco"
})

dados.head()
# Out:
#                date  Consumo_kWh  Lagging_Current_Reactive.Power_kVarh  \
# 0  29/04/2018 07:15         2.88                                  3.82
# 1  04/10/2018 12:00        60.77                                 48.02
# 2  26/01/2018 11:30       120.42                                 59.65
# 3  02/06/2018 14:30         3.13                                  0.00
# 4  07/12/2018 15:00        58.86                                 20.99
#
#    Leading_Current_Reactive_Power_kVarh  FP_Atraso  FP_Avanco WeekStatus  \
# 0                                   0.0      60.20     100.00    Weekend
# 1                                   0.0      78.46     100.00    Weekday
# 2                                   0.0      89.61     100.00    Weekday
# 3                                  16.6     100.00      18.53    Weekend
# 4                                   0.0      94.19     100.00    Weekday
#
#   Day_of_week     Load_Type
# 0      Sunday    Light_Load
# 1    Thursday  Maximum_Load
# ...

# %% [markdown]
# # Dataset 3 — Power Consumption of Tetouan City (UCI)
#
# Fonte: https://archive.ics.uci.edu/dataset/849/power+consumption+of+tetouan+city
#
# Situação:
#
# Uma equipe responsável pelo planejamento da distribuição de energia em Tétouan deseja identificar qual das três zonas apresenta o maior pico de consumo e observar as condições ambientais registradas nos momentos de maior demanda

# %%
df3 = pd.read_csv('/content/Tetuan City power consumption.csv')

# %%
df3.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed'], dtype='object')

# %%
#Renomeie as três variáveis de consumo para Consumo_Zona_1, Consumo_Zona_2 e Consumo_Zona_3

df3 = df3.rename(columns={
    'Temperature': 'Consumo_Zona_1',
    'Humidity': 'Consumo_Zona_2',
    'Wind Speed': 'Consumo_Zona_3'
})

# %%
#Determine o consumo máximo registrado em cada uma das três zonas.

df3['Consumo_Zona_1'] = pd.to_numeric(df3['Consumo_Zona_1'], errors='coerce')
df3['Consumo_Zona_2'] = pd.to_numeric(df3['Consumo_Zona_2'], errors='coerce')
df3['Consumo_Zona_3'] = pd.to_numeric(df3['Consumo_Zona_3'], errors='coerce')


maximos = df3[['Consumo_Zona_1', 'Consumo_Zona_2', 'Consumo_Zona_3']].max()
print(maximos)
#Identifique qual zona apresenta o maior pico de consumo na amostra.
zona_maior_pico = maximos.idxmax()
maior_pico = maximos.max()

print("Zona com maior pico:", zona_maior_pico)
print("Valor do maior pico:", maior_pico)
#Para a zona identificada, calcule 70% do valor máximo e crie um DataFrame com os registros acima desse limiar.
valor_maximo = df3[zona_maior_pico].max()
limiar = 0.70 * valor_maximo
df_acima_limiar = df3[df3[zona_maior_pico] > limiar]

print("Limiar (70%):", limiar)
print(df_acima_limiar)
# Out:
# Consumo_Zona_1    39.600
# Consumo_Zona_2    94.700
# Consumo_Zona_3     4.998
# dtype: float64
# Zona com maior pico: Consumo_Zona_2
# Valor do maior pico: 94.7
# Limiar (70%): 66.28999999999999
#       Consumo_Zona_1  Consumo_Zona_2  Consumo_Zona_3
# 5              12.42           72.30           0.081
# 6              14.58           80.60           0.080
# 7              14.99           69.14           0.074
# 8              11.16           70.80           0.080
# 9              19.21           89.40           4.923
# ...              ...             ...             ...
# 5236           16.34           82.30           0.069
# 5237           17.20           80.10           4.909
# 5240           16.93           76.10           0.082
# 5241           10.93           67.88           0.082
# 5243           16.99           83.00           0.081
#
# [3095 rows x 3 columns]

# %%
#Conte os registros e calcule o percentual que eles representam.

# Conta os registros acima do limiar
quantidade = len(df_acima_limiar)

# Calcula o percentual em relação ao total da amostra
percentual = (quantidade / len(df3)) * 100

print("Quantidade de registros:", quantidade)
print("Percentual:", percentual, "%")
# Out:
# Quantidade de registros: 3095
# Percentual: 59.019832189168575 %

# %%
#Calcule a temperatura média e crie um segundo DataFrame contendo consumo acima do limiar e temperatura acima da média.

# Calcula a temperatura média
temperatura_media = df3['Consumo_Zona_1'].mean()

# Cria o DataFrame com as duas condições
df_acima_limiar_temperatura = df3[
    (df3[zona_maior_pico] > limiar) &
    (df3['Consumo_Zona_1'] > temperatura_media)
]

print("Temperatura média:", temperatura_media)
print(df_acima_limiar_temperatura)
# Out:
# Temperatura média: 18.855991606257156
#       Consumo_Zona_1  Consumo_Zona_2  Consumo_Zona_3
# 9              19.21           89.40           4.923
# 14             21.03           86.50           0.068
# 27             26.92           70.20           4.909
# 29             25.37           77.80           4.918
# 31             24.60           91.30           4.918
# ...              ...             ...             ...
# 5215           26.22           82.50           4.916
# 5228           25.35           82.30           4.914
# 5230           18.88           87.60           4.917
# 5233           26.36           76.30           4.920
# 5235           21.89           68.49           4.913
#
# [1251 rows x 3 columns]

# %%
#Compare os dois conjuntos e explique o que ocorreu com a quantidade de registros após a inclusão da condição ambiental.

# Quantidade antes da condição de temperatura
qtd_antes = len(df_acima_limiar)

# Quantidade depois de adicionar a condição de temperatura
qtd_depois = len(df_acima_limiar_temperatura)

# Diferença
diferenca = qtd_antes - qtd_depois

# Percentual de redução
percentual_reducao = (diferenca / qtd_antes) * 100

print("Registros antes:", qtd_antes)
print("Registros depois:", qtd_depois)
print("Registros removidos:", diferenca)
print(f"Redução: {percentual_reducao:.2f}%")
# Out:
# Registros antes: 3095
# Registros depois: 1251
# Registros removidos: 1844
# Redução: 59.58%

# %% [markdown]
# #**Dataset 4 — Solar Power Generation Data (Kaggle)**
#
# Fonte: https://www.kaggle.com/datasets/anikannal/solar-power-generation-data
#
# Situação
#
# Uma equipe de operação de uma usina fotovoltaica deseja localizar períodos de alta geração e identificar quais inversores aparecem com maior frequência nesses momentos. Nesta atividade, o foco inicial será o arquivo de geração da planta, sem realizar junção com o arquivo de sensores.

# %%
import pandas as pd

# %%
df4 = pd.read_csv('/content/solar_sample_new.csv')

# %%
df4.head()
# Out:
#           DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0  10-06-2020 19:00  uHbuxQJl8lW7ozc      0.00     0.000     6645.000
# 1  28-05-2020 00:15  rGa61gmuvPhdLxV      0.00     0.000        0.000
# 2  17-05-2020 15:15  sjndEbLyjtCKgGv   7333.88   718.062     6442.000
# 3  01-06-2020 04:15  ih0vzX44oOqAx2f      0.00     0.000        0.000
# 4  17-05-2020 09:00  z9Y9gH1T5YWrNuG   7665.50   750.438      961.375
#
#    TOTAL_YIELD
# 0  7240508.000
# 1  7206549.000
# 2  7036055.000
# 3  6308232.000
# 4  7021701.375

# %%
df4.rename(columns={
    'DC_POWER': 'Potencia_CC',
    'AC_POWER': 'Potencia_CA',
    'DAILY_YIELD': 'Geracao_Diaria'
}, inplace=True)

# %%
df4.head()
# Out:
#           DATE_TIME       SOURCE_KEY  Potencia_CC  Potencia_CA  \
# 0  10-06-2020 19:00  uHbuxQJl8lW7ozc         0.00        0.000
# 1  28-05-2020 00:15  rGa61gmuvPhdLxV         0.00        0.000
# 2  17-05-2020 15:15  sjndEbLyjtCKgGv      7333.88      718.062
# 3  01-06-2020 04:15  ih0vzX44oOqAx2f         0.00        0.000
# 4  17-05-2020 09:00  z9Y9gH1T5YWrNuG      7665.50      750.438
#
#    Geracao_Diaria  TOTAL_YIELD
# 0        6645.000  7240508.000
# 1           0.000  7206549.000
# 2        6442.000  7036055.000
# 3           0.000  6308232.000
# 4         961.375  7021701.375

# %%
df4.shape
# Out:
# (13756, 6)

# %%
print(f'Número de linhas: {df4.shape[0]}')
print(f'Número de colunas: {df4.shape[1]}')
# Out:
# Número de linhas: 13756
# Número de colunas: 6

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13756 entries, 0 to 13755
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATE_TIME       13756 non-null  object
#  1   SOURCE_KEY      13756 non-null  object
#  2   Potencia_CC     13756 non-null  float64
#  3   Potencia_CA     13756 non-null  float64
#  4   Geracao_Diaria  13756 non-null  float64
#  5   TOTAL_YIELD     13756 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 644.9+ KB

# %%
df4.describe()
# Out:
#         Potencia_CC   Potencia_CA  Geracao_Diaria   TOTAL_YIELD
# count  13756.000000  13756.000000    13756.000000  1.375600e+04
# mean    3135.848662    306.695495     3319.235216  6.978829e+06
# std     4023.069619    393.124284     3142.249927  4.162164e+05
# min        0.000000      0.000000        0.000000  6.183645e+06
# 25%        0.000000      0.000000        0.000000  6.509779e+06
# 50%      370.071500     35.771400     2730.425000  7.146218e+06
# 75%     6350.562500    622.065500     6293.782500  7.267996e+06
# max    14416.100000   1405.590000     9163.000000  7.846821e+06

# %%
potencia_ca_max = df4['Potencia_CA'].max()

print(f'Maior potência CA registrada: {potencia_ca_max}')
# Out:
# Maior potência CA registrada: 1405.59

# %%
limite_70 = 0.7 * potencia_ca_max
print(f'Limite de 70% da potência máxima: {limite_70:.2f}')
# Out:
# Limite de 70% da potência máxima: 983.91

# %%
df_alta_geracao = df4[df4['Potencia_CA'] > limite_70]

# %%
print(f'Quantidade de registros de alta geração: {len(df_alta_geracao)}')
# Out:
# Quantidade de registros de alta geração: 1185

# %%
percentual = len(df_alta_geracao) / len(df4) * 100
print(f'Percentual da amostra: {percentual:.2f}%')
# Out:
# Percentual da amostra: 8.61%

# %%
df_alta_geracao['SOURCE_KEY'].value_counts()
# Out:
# SOURCE_KEY
# adLQvlD726eNBSB    68
# McdE0feGgRqW7Ca    65
# ZnxXDlPa8U1GXgE    63
# pkci93gMrogZuBj    62
# ZoEaEvLYb1n2sOq    61
# 1IF53ai7Xc0U56Y    59
# YxYtjZvoooNbGkE    58
# sjndEbLyjtCKgGv    57
# z9Y9gH1T5YWrNuG    56
# uHbuxQJl8lW7ozc    55
# zVJPv84UY57bAof    54
# zBIq5rxdHJRwDNY    53
# ih0vzX44oOqAx2f    53
# WRmjgnKYAwPKWDb    52
# 3PZuoBAID5Wc2HD    51
# iCRJl6heRkivqQ3    51
# VHMLBKoKgIrUVDU    51
# wCURE6d3bPkepu2    49
# rGa61gmuvPhdLxV    43
# 7JYdWkrLSPkdwr4    43
# 1BY6WEcLGh8j5v7    42
# bvBOhCH3iADSZry    39
# Name: count, dtype: int64

# %%
inversor_mais_frequente = df_alta_geracao['SOURCE_KEY'].value_counts().idxmax()
print(f'Inversor mais frequente nos registros de alta geração: {inversor_mais_frequente}')
# Out:
# Inversor mais frequente nos registros de alta geração: adLQvlD726eNBSB

# %%
print("DEUS ABENÇOE ESTE DATASET")
# Out:
# DEUS ABENÇOE ESTE DATASET

# %% [markdown]
# #Dataset 5 — Wind & Solar Energy Production (Kaggle)

# %%
df5 = pd.read_csv('/content/Energy Production Dataset.csv')

# %%
df5 = df5.pivot_table(
    index=['Date', 'Start_Hour', 'End_Hour', 'Day_of_Year', 'Season', 'Month_Name'],
    columns='Source',
    values='Production',
    fill_value=0
).reset_index()

# %%
df5.rename(columns={
    'Solar': 'Geracao_Solar',
    'Wind': 'Geracao_Eolica',
                    }, inplace=True)

# %%
df5.head()
# Out:
# Source      Date  Start_Hour  End_Hour  Day_of_Year  Season Month_Name  \
# 0       1/1/2020          15        16            1  Winter    January
# 1       1/1/2020          19        20            1  Winter    January
# 2       1/1/2021           4         5            1  Winter    January
# 3       1/1/2021          12        13            1  Winter    January
# 4       1/1/2021          19        20            1  Winter    January
#
# Source  Geracao_Solar  Geracao_Eolica
# 0                 0.0          1323.0
# 1                 0.0          1181.0
# 2                 0.0           998.0
# 3              1994.0             0.0
# 4                 0.0          1425.0

# %%
max_solar = df5['Geracao_Solar'].max()

# %%
max_eolica = df5['Geracao_Eolica'].max()

# %%
limiar = 0.70
limite_solar = limiar * max_solar
limite_eolica = limiar * max_eolica

# %%
df_alta_solar = df5[df5['Geracao_Solar'] >= limite_solar].copy()

# %%
df_alta_eolica = df5[df5['Geracao_Eolica'] >= limite_eolica].copy()

# %%
total_registros = len(df5)
qtd_alta_solar = len(df_alta_solar)
qtd_alta_eolica = len(df_alta_eolica)
pct_alta_solar = (qtd_alta_solar / total_registros) * 100
pct_alta_eolica = (qtd_alta_eolica / total_registros) * 100

# %%
print(f"Total de registros na base: {total_registros:,}")
print("-" * 45)
print(f"Alta Geração Solar  : {qtd_alta_solar:,} registros ({pct_alta_solar:.2f}%)")
print(f"Alta Geração Eólica : {qtd_alta_eolica:,} registros ({pct_alta_eolica:.2f}%)")
# Out:
# Total de registros na base: 10,373
# ---------------------------------------------
# Alta Geração Solar  : 45 registros (0.43%)
# Alta Geração Eólica : 245 registros (2.36%)

# %%
if pct_alta_solar > pct_alta_eolica:
    diferenca = pct_alta_solar - pct_alta_eolica
    print(f"A fonte SOLAR opera com maior frequência acima de 70% do seu pico "
          f"({pct_alta_solar:.2f}% vs {pct_alta_eolica:.2f}% eólica, diferença de +{diferenca:.2f} p.p.).")
elif pct_alta_eolica > pct_alta_solar:
    diferenca = pct_alta_eolica - pct_alta_solar
    print(f"A fonte EÓLICA opera com maior frequência acima de 70% do seu pico "
          f"({pct_alta_eolica:.2f}% vs {pct_alta_solar:.2f}% solar, diferença de +{diferenca:.2f} p.p.).")
else:
    print(f"Ambas as fontes apresentaram a mesma frequência de operação acima de 70% "
          f"({pct_alta_solar:.2f}%).")
# Out:
# A fonte EÓLICA opera com maior frequência acima de 70% do seu pico (2.36% vs 0.43% solar, diferença de +1.93 p.p.).

# %% [markdown]
# Como as usinas solares e eólicas possuem capacidades instaladas e escalas distintas, comparar sua produção por valores fixos em megawatts distorce a análise em favor da fonte de maior porte.     Este codigo esta condisente com oq foi pedido na atividade

# %% [markdown]
# #Dataset 6 — Individual Household Electric Power Consumption (UCI)
# Fonte: https://archive.ics.uci.edu/dataset/235/individual+household+electric+power+consumption
#
# Situação:
#
# Uma residência possui monitoramento elétrico detalhado e deseja identificar episódios de demanda elevada que também apresentem corrente acima do comportamento médio. O dataset é o mesmo utilizado como referência em aula, mas o critério de análise será diferente.

# %%
df6 = pd.read_csv("/content/energydata_SAMPLE.csv")

# %%
df6.columns
# Out:
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3'], dtype='object')

# %%
#Carregue a nova amostra e organize os atributos utilizando nomes mais simples.

df6 = df6.rename(columns={
    'Appliances': 'eletrodomesticos',
    'lights': 'luzes',
    'T1': 'temp1',
    'T2': 'temp2',
    'T3':'temp3',
    'RH_1':'unidade1',
    'RH_2': 'unidade2',
    'RH_3': 'unidade3'

})

# %%
#Determine o valor máximo de potência ativa.
df6["eletrodomesticos"].max()
# Out:
# 770

# %%
#Calcule 75% do valor máximo e crie um DataFrame contendo registros acima desse limite.

valor_maximo = df6["eletrodomesticos"].max()

limite = 0.75 * valor_maximo

df_acima_limite = df6[df6["eletrodomesticos"] > limite]

print("Valor máximo:", valor_maximo)
print("Limite de 75%:", limite)
print(df_acima_limite)
# Out:
# Valor máximo: 770
# Limite de 75%: 577.5
#       eletrodomesticos  luzes    temp1  unidade1    temp2  unidade2    temp3  \
# 352                620      0  24.3900   44.3333  25.3700   37.7360  26.7300
# 427                650      0  20.8900   36.7000  18.2900   39.6633  21.2000
# 696                590     30  19.8567   47.6633  18.7000   34.1000  18.4267
# 744                740     20  19.5000   42.1333  18.2600   39.1967  19.8900
# 916                750     30  22.4300   43.0000  21.9267   40.1333  21.2300
# 993                690     10  22.5333   45.0267  22.0667   39.7900  22.3900
# 1173               580      0  21.6000   34.6267  19.5000   33.7600  22.5750
# 1182               600     20  24.8900   48.1333  28.9175   37.9475  27.1000
# 1196               580      0  23.6333   47.2267  24.8140   43.4720  26.1667
# 1202               590     20  21.2900   36.6333  19.3900   35.3633  23.5667
# 1323               680      0  20.2900   39.3333  19.6000   38.3600  20.5333
# ...

# %%
#Calcule a quantidade e o percentual de registros selecionados.

quantidade = len(df_acima_limite)
percentual = (quantidade / len(df6)) * 100

print("Quantidade de registros:", quantidade)
print("Percentual de registros:", round(percentual, 2), "%")
# Out:
# Quantidade de registros: 17
# Percentual de registros: 0.86 %

# %%
#Calcule a corrente média da amostra.

df6["corrente"] = df6["eletrodomesticos"] / 220
corrente_media = df6["corrente"].mean()

# %%
#Crie um segundo DataFrame contendo simultaneamente potência ativa acima de 75% do máximo e corrente acima da média.
df_filtrado = df6[
    (df6["eletrodomesticos"] > limite) &
    (df6["corrente"] > corrente_media)
]

print(df_filtrado)
# Out:
#       eletrodomesticos  luzes    temp1  unidade1    temp2  unidade2    temp3  \
# 352                620      0  24.3900   44.3333  25.3700   37.7360  26.7300
# 427                650      0  20.8900   36.7000  18.2900   39.6633  21.2000
# 696                590     30  19.8567   47.6633  18.7000   34.1000  18.4267
# 744                740     20  19.5000   42.1333  18.2600   39.1967  19.8900
# 916                750     30  22.4300   43.0000  21.9267   40.1333  21.2300
# 993                690     10  22.5333   45.0267  22.0667   39.7900  22.3900
# 1173               580      0  21.6000   34.6267  19.5000   33.7600  22.5750
# 1182               600     20  24.8900   48.1333  28.9175   37.9475  27.1000
# 1196               580      0  23.6333   47.2267  24.8140   43.4720  26.1667
# 1202               590     20  21.2900   36.6333  19.3900   35.3633  23.5667
# 1323               680      0  20.2900   39.3333  19.6000   38.3600  20.5333
# ...
